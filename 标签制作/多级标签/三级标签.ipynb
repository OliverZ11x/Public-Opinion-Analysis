# %%
text="""三级指标
安全架构
安全架构
安全架构
安全架构
安全架构
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
安全配置
操控性感受
操控性感受
操控性感受
操控性感受
操控性感受
操控性感受
操控性感受
操作便利性
操作便利性
驾驶模式
驾驶模式
驾驶模式
驾驶模式
驾驶模式
驾驶模式
驾驶模式
其他操控
其他操控
其他操控
其他操控
其他操控
其他操控
其他操控
其他操控
通过性
通过性
通过性
通过性
通过性
通过性
通过性
制动
制动
制动
制动
制动
制动
制动
转向系统
转向系统
转向系统
转向系统
转向系统
转向系统
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
动力性感受
发动机结构
发动机结构
发动机结构
发动机结构
发动机结构
发动机结构
驱动
驱动
驱动
驱动
驱动
驱动
车内储物空间
车内储物空间
车内储物空间
车内储物空间
车内储物空间
车内储物空间
车内储物空间
车内储物空间
车内储物空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
乘坐空间
行李厢空间
行李厢空间
按键/旋钮
按键/旋钮
按键/旋钮
按键/旋钮
按键/旋钮
按键/旋钮
按键/旋钮
按键/旋钮
车内灯
车内灯
车内灯
车内灯
车内灯
车内灯
方向盘
方向盘
方向盘
方向盘
方向盘
方向盘
方向盘
方向盘
方向盘
方向盘
内饰整体
内饰整体
内饰整体
内饰整体
内饰整体
内饰整体
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
其他内饰
饰板/饰条
饰板/饰条
饰板/饰条
其他配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
车载互联配置
显示屏
显示屏
显示屏
显示屏
显示屏
仪表台
仪表台
仪表台
仪表台
仪表台
仪表台
音响
音响
音响
音响
娱乐配置
娱乐配置
娱乐配置
娱乐配置
娱乐配置
娱乐配置
娱乐配置
娱乐配置
中控台
中控台
中控台
中控台
中控台
中控台
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
底盘/悬架
抖动震动
抖动震动
抖动震动
抖动震动
抖动震动
抖动震动
空调
空调
空调
空调
空调
空调
空调
电机
电机
电机
电机
电机
电机
电机
电机
显示屏
OTA
OTA
辅助停车
辅助停车
辅助停车
远程车控
远程车控
远程车控
远程车控
远程车控
远程车控
远程车控
智能导航
智能导航
智能导航
智能导航
智能导航
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化服务
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
智能化设备
自动（辅助）驾驶
自动（辅助）驾驶
自动（辅助）驾驶
自动（辅助）驾驶
自动（辅助）驾驶
自动（辅助）驾驶
价格政策
价格政策
价格政策
价格政策
价格政策
价格
价格
性能
性能
性能
外观
外观
内饰
内饰
内饰
服务
服务
品牌
品牌
置换
置换
出行
出行
需求
需求
家庭出行
家庭出行
商务用车
商务用车
驾驶乐趣
驾驶乐趣
网约车
网约车
自驾游
自驾游
上下班
上下班
接送小孩
接送小孩
社交交友
社交交友
身份象征
身份象征
"""

# %%
labels = text.split('\n')
unique_labels = list(set(labels))
filtered_list = [label for label in unique_labels if label != '']
print(unique_labels)
print(filtered_list)
# Out:
# ['', '需求', '智能化设备', '交车过程', '品牌', '安全配置', '价格政策', '音响', '智能导航', '发动机结构', '其他配置', '智能化服务', '使用成本', '驾驶乐趣', '底盘/悬架', '内饰整体', '舒适性配置', '电池', '商务用车', '中控台', '品牌类别', '其他舒适性', '4S店服务总体', '外观造型', '仪表台', '行李厢空间', '内饰', '制动', '接送小孩', '售后服务总体', '车身整体', '服务质量', '娱乐配置', '服务时间', '家庭出行', '自动（辅助）驾驶', '抖动震动', '身份象征', '经销商设施', '其他服务', '保值率', '安全架构', '服务费用', '动力性感受', '电机', '转向系统', '外后视镜', '饰板/饰条', '动力类型', '服务人员', '电耗', '空调', '外观', '通过性', 'OTA', '上下班', '车轮', '服务', '驱动', '视野', '驾驶模式', '方向盘', '销售人员', '网约车', '车内储物空间', '充电模式', '座椅', '充电便利性', '社交交友', '服务设施', '品牌总体', '远程车控', '操控性感受', '车门', '开始购车经历', '乘坐空间', '车窗', '交易过程', '按键/旋钮', '出行', '续航', '其他操控', '噪音异响控制', '车外灯', '操作便利性', '服务项目', '自驾游', '置换', '车载互联配置', '性能', '辅助停车', '显示屏', '价格', '其他外观', '舒适性感受', '性价比', '三级指标', '其他内饰', '车内灯']
# ...

# %%
with open('3label.txt', 'w') as file:
    for item in filtered_list:
        file.write(item + '\n')

# %%
# 从3label.txt中读取数据
with open('3label.txt', 'r') as file:
    data = file.readlines()
